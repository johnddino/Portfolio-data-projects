# %%
#importing csv using pandas

import pandas as pd

df = pd.read_csv(r'C:/Users/SetsunaLT/Documents/Data analytics/Portfolio projects/3/Consumer_Complaints_Edit.csv')

# %%
#1st 5 rows on the dataframe

df.head()
# Out:
#    Complaint ID Submitted via Date submitted Date received State  \
# 0       4848023      Referral     2021-10-24    2021-10-27    NY
# 1       3621464           Web     2020-04-24    2020-04-24    FL
# 2       5818349           Web     2022-07-27    2022-07-27    CA
# 3       7233015      Referral     2023-07-10    2023-07-11    CA
# 4       5820224      Referral     2022-07-27    2022-07-28    VA
#
#                                              Product  \
# 0                                           Mortgage
# 1  Money transfer, virtual currency, or money ser...
# 2  Credit reporting, credit repair services, or o...
# 3                        Credit card or prepaid card
# 4                        Credit card or prepaid card
#
#                                   Sub-product  \
# 0                  Conventional home mortgage
# 1                   Refund anticipation check
# 2                            Credit reporting
# 3                General-purpose prepaid card
# ...

# %%
# Last 5 rows

df.tail()
# Out:
#        Complaint ID Submitted via Date submitted Date received State  \
# 62511       2501211           Web     2017-06-04    2017-06-04    TX
# 62512       2472406      Referral     2017-05-01    2017-05-05    VA
# 62513       3704015           Web     2020-06-17    2020-06-17    TN
# 62514       2488973      Referral     2017-05-19    2017-05-19    GA
# 62515       6234542           Web     2022-11-22    2022-11-22    CA
#
#                                                  Product  \
# 62511                        Checking or savings account
# 62512                        Checking or savings account
# 62513  Credit reporting, credit repair services, or o...
# 62514                                           Mortgage
# 62515  Money transfer, virtual currency, or money ser...
#
#                             Sub-product  \
# 62511                  Checking account
# 62512  Other banking product or service
# 62513            Credit repair services
# ...

# %%
# Filtering status with open

df[df["Status"] == "Open"]
# Out:
#        Complaint ID Submitted via Date submitted Date received State  \
# 3           7233015      Referral     2023-07-10    2023-07-11    CA
# 69          7388226           Web     2023-08-11    2023-08-11    AZ
# 94          7387569           Web     2023-08-11    2023-08-11    TX
# 105         7387966           Web     2023-08-11    2023-08-11    NJ
# 145         7312071           Web     2023-07-28    2023-07-28    MD
# ...             ...           ...            ...           ...   ...
# 58664       7200180           Web     2023-07-03    2023-07-03    NY
# 58705       7175401           Web     2023-06-27    2023-06-27    CA
# 58780       7210770           Web     2023-07-05    2023-07-05    CA
# 58795       7258226           Web     2023-07-17    2023-07-17    CA
# 59642       7193203         Phone     2023-06-29    2023-06-29    CT
#
#                                                  Product  \
# 3                            Credit card or prepaid card
# ...

# %%
# Locate row number 155

df.iloc[155]
# Out:
# Complaint ID                                                              4845144
# Submitted via                                                                 Web
# Date submitted                                                         2021-10-26
# Date received                                                          2021-10-26
# State                                                                          GA
# Product                                                           Debt collection
# Sub-product                                                      Credit card debt
# Issue                                           Attempts to collect debt not owed
# Sub-issue                                       Debt was result of identity theft
# Company public response         Company has responded to the consumer and the ...
# Company response to consumer                      Closed with non-monetary relief
# ...

# %%
#list in row 155

list(df.iloc[155])
# Out:
# [np.int64(4845144),
#  'Web',
#  '2021-10-26',
#  '2021-10-26',
#  'GA',
#  'Debt collection',
#  'Credit card debt',
#  'Attempts to collect debt not owed',
#  'Debt was result of identity theft',
#  'Company has responded to the consumer and the CFPB and chooses not to provide a public response',
#  'Closed with non-monetary relief',
#  'Yes',
#  'Closed']

# %%
#set in row 155

set(df.iloc[155])
# Out:
# {'2021-10-26',
#  np.int64(4845144),
#  'Attempts to collect debt not owed',
#  'Closed',
#  'Closed with non-monetary relief',
#  'Company has responded to the consumer and the CFPB and chooses not to provide a public response',
#  'Credit card debt',
#  'Debt collection',
#  'Debt was result of identity theft',
#  'GA',
#  'Web',
#  'Yes'}
